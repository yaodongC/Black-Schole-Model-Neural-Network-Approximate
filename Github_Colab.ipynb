# %% [markdown]
# <a href="https://colab.research.google.com/github/yaodongC/Black-Schole-Model-Neural-Network-Approximate/blob/master/Github_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mount Google drive

# %%
try:
    from google.colab import drive
    drive.mount("/content/drive/", force_remount=True)
    google_drive_prefix = "/content/drive/My Drive"
    data_prefix = "{}/semantic_kitti/".format(google_drive_prefix)
    # repo_prefix = "{}/mnist/".format(google_drive_prefix)
except ModuleNotFoundError: 
    data_prefix = "data/"
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Clone Github Repo
# ## Set-up Github Repo

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/Cylinder3D' 
# replace with your Github username 
GIT_USERNAME = "yaodongC" 
# definitely replace with your
GIT_TOKEN = "e3275693c0f30b436fccd11491278b7de431ae1a"  
# Replace with your github repository in this case we want 
# to clone the repository
GIT_REPOSITORY = "Cylinder3D" 

# PROJECT_PATH = join(google_drive_prefix, MY_GOOGLE_DRIVE_PATH)
PROJECT_PATH =  "{}/Cylinder3D/".format(google_drive_prefix)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# !pwd
# !ls
# Out:
# PROJECT_PATH:  /content/drive/My Drive/Cylinder3D/
# mkdir: cannot create directory ‘/content/drive/My Drive/Cylinder3D/’: File exists
# GIT_PATH:  https://e3275693c0f30b436fccd11491278b7de431ae1a@github.com/yaodongC/Cylinder3D.git
# /content
# drive  sample_data

# %% [markdown]
# ## Clone the Github Repo to local run-time

# %%
# !git clone "{GIT_PATH}" ./temp      # clone github repository to temp folder
# !mv ./temp/* "{PROJECT_PATH}"       # move all files/folders in temp folder to folder defined in project path
# !rm -rf ./temp                      # remove all the files/folders in temp folder
# !rsync -aP --exclude=data/ "{PROJECT_PATH}"/*  ./   # use remote sync to copy from google drive to local runtime google colab
                                                    # but exclude data folder
                                                    # https://www.computerhope.com/unix/rsync.htm

# %%
# !mkdir "./Cylinder3D"  
# %cd "./Cylinder3D"    # Change directory to the location defined in project_path
# !git clone "{GIT_PATH}"          # clone the github repository
# Out:
# [Errno 2] No such file or directory: 'Cylinder3D # Change directory to the location defined in project_path'
# /content
# Cloning into 'Cylinder3D'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 123 (delta 47), reused 72 (delta 16), pack-reused 0
# Receiving objects: 100% (123/123), 674.04 KiB | 19.26 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %% [markdown]
# ## Clone the Github Repo to Google Drive

# %%
# !pwd
# %cd "{PROJECT_PATH}"    # Change directory to the location defined in project_path
# %cd ./drive/My Drive/Cylinder3D 
# !git clone "{GIT_PATH}" # clone the github repository
# Out:
# /content/drive/My Drive/Cylinder3D
# [Errno 2] No such file or directory: './drive/My Drive/Cylinder3D'
# /content/drive/My Drive/Cylinder3D
# Cloning into 'Cylinder3D'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 123 (delta 47), reused 72 (delta 16), pack-reused 0
# Receiving objects: 100% (123/123), 674.04 KiB | 14.65 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %% [markdown]
# # Copy Data from Google Drive

# %%
print(data_prefix)
# Out:
# /content/drive/My Drive/semanticKITTI/

# %%
# !ls "{data_prefix}"
# Out:
# data_odometry_calib.zip  data_odometry_labels.zip  data_odometry_velodyne.zip

# %%
# !cp -r "{data_prefix}" /content/Cylinder3D/data/dataset/
# Out:
# cp: error reading '/content/drive/My Drive/semantic_kitti/data_odometry_velodyne.zip': No space left on device

# %% [markdown]
# # Dowload data to drive or local run-time

# %%
Semantickitti_PATH =  "./data/dataset/semantic_kitti"

# %cd "{data_prefix}"
# Out:
# /content/drive/My Drive/semanticKITTI

# %%
# !pwd
# !wget "https://s3.eu-central-1.amazonaws.com/avg-kitti/data_odometry_velodyne.zip"
# Out:
# /content/drive/My Drive/semanticKITTI
# --2021-02-10 22:44:34--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_odometry_velodyne.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.47.47
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.47.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84786535790 (79G) [application/zip]
# Saving to: ‘data_odometry_velodyne.zip’
#
# data_odometry_velod 100%[===================>]  78.96G  28.8MB/s    in 48m 21s
#
# 2021-02-10 23:32:55 (27.9 MB/s) - ‘data_odometry_velodyne.zip’ saved [84786535790/84786535790]

# %% [markdown]
# ## Unzip

# %%
# !pwd
# %cd /content
# !pwd
# %cd /content/Cylinder3D/data/dataset/semantic_kitti/
# !ls
# Out:
# /content
# /content
# /content
# /content/Cylinder3D/data/dataset/semantic_kitti

# %%
# !pwd
# %cd /content/drive/MyDrive/Cylinder3D/Cylinder3D/data/dataset/semantic_kitti/
# !ls
# Out:
# /content
# /content/drive/MyDrive/Cylinder3D/Cylinder3D/data/dataset/semantic_kitti
# data_odometry_calib.zip   data_odometry_velodyne.zip
# data_odometry_labels.zip  readme

# %%
# !ls
# !unzip data_odometry_velodyne.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: dataset/sequences/19/velodyne/001483.bin
#  extracting: dataset/sequences/19/velodyne/003096.bin
#  extracting: dataset/sequences/19/velodyne/000431.bin
#  extracting: dataset/sequences/19/velodyne/001799.bin
#  extracting: dataset/sequences/19/velodyne/003910.bin
#  extracting: dataset/sequences/19/velodyne/003131.bin
#  extracting: dataset/sequences/19/velodyne/002086.bin
#  extracting: dataset/sequences/19/velodyne/002409.bin
#  extracting: dataset/sequences/19/velodyne/004800.bin
#  extracting: dataset/sequences/19/velodyne/003371.bin
#  extracting: dataset/sequences/19/velodyne/004715.bin
#  extracting: dataset/sequences/19/velodyne/002157.bin
#  extracting: dataset/sequences/19/velodyne/001259.bin
#  extracting: dataset/sequences/19/velodyne/002279.bin
#  extracting: dataset/sequences/19/velodyne/003306.bin
#  extracting: dataset/sequences/19/velodyne/002371.bin
# ...

# %%
# !ls
# !pwd
# Out:
# data_odometry_calib.zip   data_odometry_velodyne.zip  readme
# data_odometry_labels.zip  dataset
# /content/drive/My Drive/Cylinder3D/Cylinder3D/data/dataset/semantic_kitti

# %% [markdown]
# # Run the training scripts

# %%
# !pip install yaml, torch-scatter

# %%
name=cylinder_asym_networks
gpuid=0

# !CUDA_VISIBLE_DEVICES=${gpuid}  python -u train_cylinder_asym.py 2>&1 | tee logs_dir/${name}_logs_tee.txt
